# %% [markdown]
# # Лабораторная работа №2. Основы Python

# %% [markdown]
# ## Задание

# %% [markdown]
# Выполните следующие задания:
#
# 1. Открыл в файл в Google Colab (используйте собственный форк репозитория).
# 2. Решил задачи.
# 3. Сохранил результат в ваш репозиторий github в директорию ./les02
# 4. Создайл pull request в репозиторий https://github.com/chebotarevsa/dap-2024. Название pull request должно иметь формат "ЛР-2 12002309 Лесков Е.А."

# %% [markdown]
# Задача №1. https://leetcode.com/problems/two-sum/

# %%
class Solution(object):
    def twoSum(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]
        """
        seen = {}
        
        for i, num in enumerate(nums):
            complement = target - num
            
            if complement in seen:
                return [seen[complement], i]
            
            seen[num] = i
        
        return []

# %% [markdown]
# Задача №2. https://leetcode.com/problems/palindrome-number/description/

# %%
class Solution(object):
    def isPalindrome(self, x):
        """
        :type x: int
        :rtype: bool
        """
        if x < 0:
            return False
        
        if x < 10:
            return True
        
        original = x
        reversed_num = 0
        
        while x > 0:
            digit = x % 10
            reversed_num = reversed_num * 10 + digit
            x //= 10
        
        return original == reversed_num

# %% [markdown]
# Задача №3. https://leetcode.com/problems/roman-to-integer/description/

# %%
class Solution(object):
    def romanToInt(self, s):
        """
        :type s: str
        :rtype: int
        """
        roman_map = {
            'I': 1,
            'V': 5,
            'X': 10,
            'L': 50,
            'C': 100,
            'D': 500,
            'M': 1000
        }
        
        total = 0
        n = len(s)
        
        for i in range(n):
            if i < n - 1 and roman_map[s[i]] < roman_map[s[i + 1]]:
                total -= roman_map[s[i]]
            else:
                total += roman_map[s[i]]
        
        return total

# %% [markdown]
# Задача №4. https://leetcode.com/problems/longest-common-prefix/description/

# %%
class Solution(object):
    def longestCommonPrefix(self, strs):
        """
        :type strs: List[str]
        :rtype: str
        """
        if not strs:
            return ""
        
        prefix = strs[0]
        
        for s in strs[1:]:
            while not s.startswith(prefix):
                prefix = prefix[:-1]
                if not prefix:
                    return ""
        
        return prefix

# %% [markdown]
# Задача №5. https://leetcode.com/problems/merge-two-sorted-lists/description/

# %%
class Solution(object):
    def mergeTwoLists(self, list1, list2):
        dummy = ListNode()
        curr = dummy
        
        while list1 and list2:
            if list1.val <= list2.val:
                curr.next = list1
                list1 = list1.next
            else:
                curr.next = list2
                list2 = list2.next
            curr = curr.next
        
        curr.next = list1 if list1 else list2
        
        return dummy.next

# %% [markdown]
# Задача №6. https://leetcode.com/problems/longest-substring-without-repeating-characters/description/

# %%
class Solution(object):
    def lengthOfLongestSubstring(self, s):
        char_index = {}
        max_length = 0
        start = 0
        
        for end in range(len(s)):
            if s[end] in char_index and char_index[s[end]] >= start:
                start = char_index[s[end]] + 1
            char_index[s[end]] = end
            max_length = max(max_length, end - start + 1)
        
        return max_length

# %% [markdown]
# ## Ответы
#
# 1. **Что такое динамическая типизация и чем она отличается от статической?**
#    Динамическая типизация — это подход, при котором тип переменной определяется во время выполнения программы, а не на этапе компиляции. Переменная может менять тип в процессе работы.
#    Статическая типизация — типы переменных известны и проверяются на этапе компиляции, изменение типа невозможно.
#
#    **Пример (динамическая, Python):**
#    ```python
#    x = 5      # int
#    x = "hi"   # теперь str
#
# ## Ответы на вопросы по Python
#
# 1. **Что такое динамическая типизация и чем она отличается от статической?**
#    Динамическая типизация — тип переменной определяется во время выполнения. Переменная может менять тип.
#    Статическая — типы проверяются на этапе компиляции, изменение невозможно.
#
#    **Пример (Python):**
#    ```python
#    x = 5      # int
#    x = "hi"   # теперь str
#    ```
#    ```C++
#    Пример (C++):
#    int x = 5;
#    x = "hi"; // ошибка
#    ```
#
# 2. **Чем отличается цикл for в Python от цикла for в C++?**
#    Python: цикл по итерируемому объекту
#    for i in range(5):  # i = 0,1,2,3,4
#
#    C++: счётчик-цикл
#    for (int i = 0; i < 5; i++) { ... }
#
# 3. **Для чего предназначены continue и break?**
#    continue — пропустить текущую итерацию
#    break — выйти из цикла полностью
#
#    ```python
#    for i in range(5):
#        if i == 2: continue  # пропустит 2
#        if i == 4: break     # остановит
#        print(i)             # 0,1,3
#     ```
#
# 4. **Как определить функцию? Может ли она возвращать несколько значений?**
#    ```python
#    def func(a, b):
#        return a + b
#
#    Да, возвращает кортеж:
#    def f(): return 1, 2, 3
#    a, b, c = f()  # 1,2,3
#    ```
#
# 5. **Что такое лямбда-функции?**
#    ```python
#    Анонимные функции:
#    f = lambda x: x * 2
#    Используются в map(), filter(), sorted()
#    ```
#
# 6. **Может ли функция содержать определение другой функции?**
#    Да — вложенные функции:
#    ```python
#    def outer():
#        def inner(): print("Hi")
#        inner()
#     ```
#
# 7. **Как определить класс? Для чего self?**
#    ```python
#    class MyClass:
#        def __init__(self, x):
#            self.x = x
#        def method(self):
#            print(self.x)
#    self — ссылка на текущий экземпляр
#    ```
#
# 8. **Как определить приватный метод? Можно ли вызвать снаружи?**
#    ```python
#    __private(self) — по соглашению
#    Нельзя вызвать напрямую: a.__private() → ошибка
#    Но технически: a._Class__private() (не рекомендуется)
#    ```
#
# 9. **Как определить статический метод?**
#    ```python
#    @staticmethod
#    def util(a, b): return a + b
#    Вызывается без экземпляра: MyClass.util(2,3)
#    ```
#
# 10. **Чем staticmethod отличается от classmethod?**
#     ```python
#     staticmethod: нет self/cls
#     classmethod: первый параметр — cls (ссылка на класс)
#     ```
#
# 11. **Как создать свой класс исключений?**
#     ```python
#     class MyError(Exception): pass
#     raise MyError("Ошибка")
#     try: ... except MyError as e: print(e)
#     ```
#
# 12. **Что такое кортеж?**
#     Неизменяемая последовательность:
#     ```python
#     t = (1, 2, "три")
#     Используется: возврат значений, ключи dict, распаковка
