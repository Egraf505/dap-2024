# %% [markdown]
# # Отчет о выполненной работе
#
# ## Введение
# Этот отчет описывает выполнение заданий, связанных с настройкой рабочей среды для работы с репозиторием и Google Colab. Целью работы было создание учетных записей, настройка интеграции между Google Colab и GitHub, а также подготовка и сдача отчета через pull request.
#
# ## Цели и задачи
# - **Цель**: Настроить рабочую среду для выполнения лабораторных работ и подготовить отчет в Google Colab.
# - **Задачи**:
#   1. Создание учетной записи на GitHub.
#   2. Форк репозитория [dap-2024](https://github.com/chebotarevsa/dap-2024).
#   3. Создание учетной записи в Google Colab.
#   4. Настройка интеграции Google Colab и GitHub.
#   5. Создание отчета в Google Colab в формате `rep.ipynb` с использованием Markdown.
#   6. Сохранение отчета в репозитории GitHub в директории `./les01`.
#   7. Создание pull request в репозиторий [dap-2024](https://github.com/chebotarevsa/dap-2024).
#   8. Сдача работы в системе "Пегас" с указанием ссылки на pull request.
#
# ## Методы и инструменты
# Для выполнения работы использовались следующие инструменты:
# - **Сервисы**: GitHub, Google Colab, система "Пегас".
# - **Формат документа**: Jupyter Notebook с Markdown-разметкой.
#
# ## Этапы выполнения работы
#
# ### 1. Создание учетной записи на GitHub
# Зарегистрирована учетная запись на платформе [GitHub](https://github.com). Логин: [укажите ваш логин].
#
# ### 2. Форк репозитория
# Выполнен форк репозитория [https://github.com/chebotarevsa/dap-2024](https://github.com/chebotarevsa/dap-2024) в личный аккаунт. Ссылка на форк: [укажите ссылку на ваш форк].
#
# ### 3. Создание учетной записи в Google Colab
# Создана учетная запись в [Google Colab](https://colab.research.google.com) с использованием Google-аккаунта.
#
# ### 4. Настройка интеграции Google Colab и GitHub
# Настроена интеграция Google Colab с GitHub через:
# - Подключение Google Colab к учетной записи GitHub.
# - Авторизацию для доступа к репозиториям.
# Теперь файлы из Google Colab можно сохранять напрямую в репозиторий GitHub.
#
# ### 5. Создание отчета в Google Colab
# Создан данный отчет в формате Jupyter Notebook (`rep.ipynb`) с использованием Markdown-разметки. Отчет включает заголовки, списки, форматированный текст и ссылки, как указано в задании.
#
# ### 6. Сохранение отчета в репозитории
# Отчет сохранен в форкнутом репозитории в директории `./les01`. Для этого использовалась встроенная функция Google Colab для сохранения файлов в GitHub.
#
# ### 7. Создание pull request
# Создан pull request в репозиторий [https://github.com/chebotarevsa/dap-2024](https://github.com/chebotarevsa/dap-2024). Название pull request: "Лабораторная работа 1 12002309 [Лесков Е.А.]".
#
# ### 8. Сдача работы в системе "Пегас"
# Работа сдана в системе "Пегас" с указанием ссылки на созданный pull request.
#
# ## Выводы
# В ходе выполнения работы были успешно созданы учетные записи на GitHub и Google Colab, выполнен форк репозитория, настроена интеграция между Google Colab и GitHub, подготовлен и сохранен отчет в формате `rep.ipynb`, а также создан pull request. Все этапы работы выполнены в соответствии с поставленными задачами. Работа сдана в системе "Пегас".
